# %% [markdown]
# # Galaxy10 Classification with ResNet-101
#
# This notebook presents a full deep learning workflow for classifying galaxy images from the Galaxy10 dataset using a ResNet-101 model. It includes custom dataset loading, preprocessing, data augmentation, model definition, training with hyperparameter tuning, and detailed performance evaluation.
#
# The notebook also visualizes results through accuracy and loss plots, confusion matrices (both raw and normalized), and a hierarchical clustering of class embeddings based on the learned feature space. The goal is to build a high-performing and interpretable image classifier suitable for academic and research-oriented use.

# %% [markdown]
# ## Imports and Setup

# %%
# Import essential libraries for data handling and visualization
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# Import PyTorch components for model building and training
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import models, transforms
from torch.utils.data import DataLoader, Dataset

# Import evaluation metrics from scikit-learn
from sklearn.metrics import (
    accuracy_score,
    balanced_accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    classification_report,
    confusion_matrix,
    ConfusionMatrixDisplay
)

# Import PCA and clustering tools for feature analysis and visualization
from sklearn.decomposition import PCA
from scipy.cluster.hierarchy import linkage, dendrogram
import plotly.express as px

# Additional utility imports
from PIL import Image
import os
from itertools import product
import torch.nn.functional as F
import warnings
warnings.filterwarnings("ignore")

# Set deterministic behavior for reproducibility
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

# Define the computation device
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %% [markdown]
# ## Dataset Preparation and Preprocessing
#
# This section defines a custom PyTorch `Dataset` for the Galaxy10 image dataset. It loads image paths and labels from subdirectories, applies necessary transformations for ResNet-101, and prepares training, validation, and test sets. Basic dataset statistics are printed to confirm successful loading.

# %%
# Define a custom Dataset class for loading Galaxy10 images
class Galaxy10Dataset(Dataset):
    def __init__(self, root_dir, transform=None):
        self.root_dir = root_dir
        self.transform = transform
        self.classes = sorted(os.listdir(root_dir))
        self.class_to_idx = {cls_name: i for i, cls_name in enumerate(self.classes)}
        self.images = []
        self.labels = []
        for cls_name in self.classes:
            cls_dir = os.path.join(root_dir, cls_name)
            for img_name in os.listdir(cls_dir):
                self.images.append(os.path.join(cls_dir, img_name))
                self.labels.append(self.class_to_idx[cls_name])

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        img_path = self.images[idx]
        label = self.labels[idx]
        image = Image.open(img_path).convert('RGB')
        if self.transform:
            image = self.transform(image)
        return image, label

# Define base image transform for ResNet input (224x224 with normalization)
base_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225])
])

# Set path to dataset directory
data_dir = 'Galaxy10_Images'

# Create dataset instances with preprocessing
train_dataset = Galaxy10Dataset(os.path.join(data_dir, 'train'), transform=base_transform)
val_dataset = Galaxy10Dataset(os.path.join(data_dir, 'val'), transform=base_transform)
test_dataset = Galaxy10Dataset(os.path.join(data_dir, 'test'), transform=base_transform)

# Retrieve class names from the training dataset
class_names = train_dataset.classes

# Display dataset statistics
print(f"Train set size: {len(train_dataset)}")
print(f"Validation set size: {len(val_dataset)}")
print(f"Test set size: {len(test_dataset)}")
print(f"Number of classes: {len(class_names)}")
# Out:
# Train set size: 15248
# Validation set size: 3269
# Test set size: 3268
# Number of classes: 10

# %% [markdown]
# ## Model Definition, Training Routine, and Hyperparameter Search
#
# This section builds a ResNet-101 with a custom classification head, defines a training loop, and performs a grid search over batch sizes and optimizers to identify the best configuration. The best model is then retrained and evaluated on the test set.

# %%
# Build a ResNet-101 model and replace its final layer for Galaxy10 classification
def get_resnet_model(num_classes, dropout_rate=0.5):
    model = models.resnet101(weights='IMAGENET1K_V1')
    num_ftrs = model.fc.in_features
    model.fc = nn.Sequential(
        nn.Dropout(dropout_rate),
        nn.Linear(num_ftrs, num_classes)
    )
    return model.to(device)

# Train the model and return the highest validation accuracy reached
def train_model(model, train_loader, val_loader, criterion, optimizer, num_epochs=20):
    best_acc = 0.0
    for epoch in range(num_epochs):
        model.train()
        for inputs, labels in train_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

        model.eval()
        val_preds, val_true = [], []
        with torch.no_grad():
            for inputs, labels in val_loader:
                inputs, labels = inputs.to(device), labels.to(device)
                outputs = model(inputs)
                _, preds = torch.max(outputs, 1)
                val_preds.extend(preds.cpu().numpy())
                val_true.extend(labels.cpu().numpy())
        acc = accuracy_score(val_true, val_preds)
        if acc > best_acc:
            best_acc = acc
    return best_acc

# Define search space for batch size and optimizer
batch_sizes = [16, 32, 64]
optimizers = ['adam', 'sgd']
results = []

# Grid search over hyperparameters
for batch_size, opt_name in product(batch_sizes, optimizers):
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=0)
    val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False, num_workers=0)

    model = get_resnet_model(num_classes=len(class_names))
    criterion = nn.CrossEntropyLoss()

    if opt_name == 'adam':
        optimizer = optim.Adam(model.parameters(), lr=0.001)
    else:
        optimizer = optim.SGD(model.parameters(), lr=0.01, momentum=0.9)

    acc = train_model(model, train_loader, val_loader, criterion, optimizer)
    results.append({'batch_size': int(batch_size), 'optimizer': opt_name, 'accuracy': acc})

    torch.cuda.empty_cache()

# Summarize grid-search results
results_df = pd.DataFrame(results)
best_idx = results_df['accuracy'].idxmax()
best_batch_size = int(results_df.loc[best_idx, 'batch_size'])
best_optimizer = results_df.loc[best_idx, 'optimizer']

# Retrain the best configuration and evaluate on the test set
model = get_resnet_model(num_classes=len(class_names))
criterion = nn.CrossEntropyLoss()
if best_optimizer == 'adam':
    optimizer = optim.Adam(model.parameters(), lr=0.001)
else:
    optimizer = optim.SGD(model.parameters(), lr=0.01, momentum=0.9)

train_model(model, train_loader, val_loader, criterion, optimizer)

model.eval()
test_loader = DataLoader(test_dataset, batch_size=best_batch_size, shuffle=False, num_workers=0)
test_preds, test_true = [], []
with torch.no_grad():
    for inputs, labels in test_loader:
        inputs, labels = inputs.to(device), labels.to(device)
        outputs = model(inputs)
        _, preds = torch.max(outputs, 1)
        test_preds.extend(preds.cpu().numpy())
        test_true.extend(labels.cpu().numpy())

torch.cuda.empty_cache()
print("Grid search completed successfully!")
# Out:
# Grid search completed successfully!

# %% [markdown]
# ## Hyperparameter Grid Search Results Visualization
#
# This section creates a heatmap to visualize validation accuracy across different combinations of batch sizes and optimizers. The best-performing configuration is printed for reference.

# %%
# Organize the grid-search results as a pivot table
pivot_table = results_df.pivot(index='batch_size', columns='optimizer', values='accuracy')

# Visualize validation accuracy across batch size and optimizer choices
plt.figure(figsize=(10, 5))
sns.heatmap(pivot_table, annot=True, fmt='.3f', cmap='viridis')
plt.title('Validation Accuracy for Hyperparameter Grid Search')
plt.xlabel('Optimizer')
plt.ylabel('Batch Size')
plt.show()

print(f"Best batch size: {best_batch_size}")
print(f"Best optimizer: {best_optimizer}")
# Out:
# Best batch size: 64
# Best optimizer: sgd

# %% [markdown]
# ## Final Training with Augmentation and Evaluation
#
# This section applies data augmentation to improve generalization, retrains the model using the best configuration, and tracks accuracy and loss over 200 epochs. After training, it evaluates the model on the test set using standard classification metrics.

# %%
# Define data-augmentation pipeline for the training set
aug_transform = transforms.Compose([
    transforms.RandomResizedCrop(224, scale=(0.8, 1.0)),
    transforms.RandomHorizontalFlip(p=0.5),
    transforms.RandomRotation(degrees=90),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225])
])

# Create datasets and data loaders
aug_train_dataset = Galaxy10Dataset(os.path.join(data_dir, 'train'), transform=aug_transform)
train_loader = DataLoader(aug_train_dataset, batch_size=32, shuffle=True,  num_workers=0)
val_loader   = DataLoader(val_dataset,      batch_size=32, shuffle=False, num_workers=0)
test_loader  = DataLoader(test_dataset,     batch_size=32, shuffle=False, num_workers=0)

# Initialize model, loss, optimizer, and scheduler
model     = get_resnet_model(num_classes=len(class_names), dropout_rate=0.3)
criterion = nn.CrossEntropyLoss(label_smoothing=0.1)
optimizer = optim.SGD(model.parameters(), lr=0.01, momentum=0.9, weight_decay=1e-4)
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=3)

# Training parameters
num_epochs     = 200
train_acc_list = []
val_acc_list   = []
train_loss_list = []
val_loss_list   = []

print("Starting training...")
for epoch in range(num_epochs):
    # --- Train phase ---
    model.train()
    running_loss, total_samples = 0.0, 0
    train_preds, train_true = [], []
    for inputs, labels in train_loader:
        inputs, labels = inputs.to(device), labels.to(device)
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item() * inputs.size(0)
        train_preds.extend(outputs.argmax(1).cpu().numpy())
        train_true.extend(labels.cpu().numpy())
        total_samples += inputs.size(0)

    train_acc_list.append(accuracy_score(train_true, train_preds))
    train_loss_list.append(running_loss / total_samples)

    # --- Validation phase ---
    model.eval()
    val_loss, total_samples = 0.0, 0
    val_preds, val_true = [], []
    with torch.no_grad():
        for inputs, labels in val_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            loss = criterion(outputs, labels)

            val_loss += loss.item() * inputs.size(0)
            val_preds.extend(outputs.argmax(1).cpu().numpy())
            val_true.extend(labels.cpu().numpy())
            total_samples += inputs.size(0)

    val_acc_list.append(accuracy_score(val_true, val_preds))
    val_loss_list.append(val_loss / total_samples)
    scheduler.step(val_loss)

    print(f"Epoch {epoch+1}/{num_epochs} - "
          f"Train Loss: {train_loss_list[-1]:.4f}, Train Acc: {train_acc_list[-1]:.4f}, "
          f"Val Loss: {val_loss_list[-1]:.4f}, Val Acc: {val_acc_list[-1]:.4f}")

    torch.cuda.empty_cache()

# Plot accuracy and loss curves
plt.figure(figsize=(10, 5))
plt.plot(train_acc_list, label="Train Acc")
plt.plot(val_acc_list,   label="Val Acc")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.title("Accuracy over Epochs")
plt.legend()
plt.grid(True)
plt.show()

plt.figure(figsize=(10, 5))
plt.plot(train_loss_list, label="Train Loss")
plt.plot(val_loss_list,   label="Val Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Loss over Epochs")
plt.legend()
plt.grid(True)
plt.show()

# Evaluate the trained model on the test set
model.eval()
test_preds, test_true = [], []
with torch.no_grad():
    for inputs, labels in test_loader:
        inputs, labels = inputs.to(device), labels.to(device)
        outputs = model(inputs)
        test_preds.extend(outputs.argmax(1).cpu().numpy())
        test_true.extend(labels.cpu().numpy())

print("Test Accuracy:",            accuracy_score(test_true, test_preds))
print("Test Balanced Accuracy:",   balanced_accuracy_score(test_true, test_preds))
print("Test Precision:",           precision_score(test_true, test_preds, average='weighted'))
print("Test Recall:",              recall_score(test_true, test_preds, average='weighted'))
print("Test F1 Score:",            f1_score(test_true, test_preds, average='weighted'))

torch.cuda.empty_cache()
# Out:
# Starting training...
# Epoch 1/200 - Train Loss: 1.2888, Train Acc: 0.6483, Val Loss: 1.0689, Val Acc: 0.7544
# Epoch 2/200 - Train Loss: 1.0237, Train Acc: 0.7638, Val Loss: 1.0015, Val Acc: 0.7700
# Epoch 3/200 - Train Loss: 0.9576, Train Acc: 0.7923, Val Loss: 0.9291, Val Acc: 0.7960
# Epoch 4/200 - Train Loss: 0.9061, Train Acc: 0.8162, Val Loss: 0.9218, Val Acc: 0.8061
# Epoch 5/200 - Train Loss: 0.8833, Train Acc: 0.8271, Val Loss: 0.8421, Val Acc: 0.8458
# Epoch 6/200 - Train Loss: 0.8666, Train Acc: 0.8390, Val Loss: 0.8691, Val Acc: 0.8314
# Epoch 7/200 - Train Loss: 0.8550, Train Acc: 0.8394, Val Loss: 0.8283, Val Acc: 0.8504
# Epoch 8/200 - Train Loss: 0.8405, Train Acc: 0.8481, Val Loss: 0.9119, Val Acc: 0.8054
# Epoch 9/200 - Train Loss: 0.8313, Train Acc: 0.8507, Val Loss: 0.8437, Val Acc: 0.8366
# Epoch 10/200 - Train Loss: 0.8208, Train Acc: 0.8563, Val Loss: 0.9035, Val Acc: 0.8223
# Epoch 11/200 - Train Loss: 0.8074, Train Acc: 0.8611, Val Loss: 0.8163, Val Acc: 0.8519
# Epoch 12/200 - Train Loss: 0.8003, Train Acc: 0.8637, Val Loss: 0.8264, Val Acc: 0.8541
# Epoch 13/200 - Train Loss: 0.7977, Train Acc: 0.8669, Val Loss: 0.8249, Val Acc: 0.8526
# Epoch 14/200 - Train Loss: 0.7868, Train Acc: 0.8716, Val Loss: 0.8605, Val Acc: 0.8324
# Epoch 15/200 - Train Loss: 0.7855, Train Acc: 0.8707, Val Loss: 0.8837, Val Acc: 0.8158
# Epoch 16/200 - Train Loss: 0.7408, Train Acc: 0.8930, Val Loss: 0.7812, Val Acc: 0.8730
# Epoch 17/200 - Train Loss: 0.7344, Train Acc: 0.8955, Val Loss: 0.7914, Val Acc: 0.8688
# Epoch 18/200 - Train Loss: 0.7276, Train Acc: 0.8976, Val Loss: 0.7657, Val Acc: 0.8783
# Epoch 19/200 - Train Loss: 0.7221, Train Acc: 0.8997, Val Loss: 0.7949, Val Acc: 0.8642
# Epoch 20/200 - Train Loss: 0.7159, Train Acc: 0.8998, Val Loss: 0.7578, Val Acc: 0.8798
# Epoch 21/200 - Train Loss: 0.7087, Train Acc: 0.9056, Val Loss: 0.8174, Val Acc: 0.8584
# Epoch 22/200 - Train Loss: 0.7115, Train Acc: 0.9054, Val Loss: 0.7804, Val Acc: 0.8706
# Epoch 23/200 - Train Loss: 0.7098, Train Acc: 0.9071, Val Loss: 0.7608, Val Acc: 0.8795
# Epoch 24/200 - Train Loss: 0.7079, Train Acc: 0.9065, Val Loss: 0.7543, Val Acc: 0.8798
# Epoch 25/200 - Train Loss: 0.7035, Train Acc: 0.9078, Val Loss: 0.7892, Val Acc: 0.8737
# Epoch 26/200 - Train Loss: 0.7031, Train Acc: 0.9069, Val Loss: 0.7515, Val Acc: 0.8819
# Epoch 27/200 - Train Loss: 0.6986, Train Acc: 0.9099, Val Loss: 0.8067, Val Acc: 0.8648
# Epoch 28/200 - Train Loss: 0.6908, Train Acc: 0.9148, Val Loss: 0.7794, Val Acc: 0.8703
# Epoch 29/200 - Train Loss: 0.6942, Train Acc: 0.9135, Val Loss: 0.8260, Val Acc: 0.8461
# Epoch 30/200 - Train Loss: 0.6930, Train Acc: 0.9126, Val Loss: 0.7741, Val Acc: 0.8838
# Epoch 31/200 - Train Loss: 0.6585, Train Acc: 0.9285, Val Loss: 0.7410, Val Acc: 0.8893
# Epoch 32/200 - Train Loss: 0.6525, Train Acc: 0.9331, Val Loss: 0.7774, Val Acc: 0.8743
# Epoch 33/200 - Train Loss: 0.6478, Train Acc: 0.9350, Val Loss: 0.7514, Val Acc: 0.8899
# Epoch 34/200 - Train Loss: 0.6408, Train Acc: 0.9390, Val Loss: 0.7875, Val Acc: 0.8740
# Epoch 35/200 - Train Loss: 0.6400, Train Acc: 0.9383, Val Loss: 0.7666, Val Acc: 0.8789
# Epoch 36/200 - Train Loss: 0.6277, Train Acc: 0.9464, Val Loss: 0.7742, Val Acc: 0.8795
# Epoch 37/200 - Train Loss: 0.6166, Train Acc: 0.9519, Val Loss: 0.7503, Val Acc: 0.8887
# Epoch 38/200 - Train Loss: 0.6154, Train Acc: 0.9510, Val Loss: 0.7587, Val Acc: 0.8871
# Epoch 39/200 - Train Loss: 0.6110, Train Acc: 0.9540, Val Loss: 0.7692, Val Acc: 0.8874
# Epoch 40/200 - Train Loss: 0.6028, Train Acc: 0.9578, Val Loss: 0.7479, Val Acc: 0.8926
# Epoch 41/200 - Train Loss: 0.5988, Train Acc: 0.9591, Val Loss: 0.7472, Val Acc: 0.8957
# Epoch 42/200 - Train Loss: 0.5977, Train Acc: 0.9590, Val Loss: 0.7521, Val Acc: 0.8923
# Epoch 43/200 - Train Loss: 0.6020, Train Acc: 0.9586, Val Loss: 0.7507, Val Acc: 0.8963
# Epoch 44/200 - Train Loss: 0.5957, Train Acc: 0.9590, Val Loss: 0.7504, Val Acc: 0.8951
# Epoch 45/200 - Train Loss: 0.5939, Train Acc: 0.9613, Val Loss: 0.7515, Val Acc: 0.8902
# Epoch 46/200 - Train Loss: 0.5918, Train Acc: 0.9633, Val Loss: 0.7564, Val Acc: 0.8899
# Epoch 47/200 - Train Loss: 0.5874, Train Acc: 0.9633, Val Loss: 0.7543, Val Acc: 0.8926
# Epoch 48/200 - Train Loss: 0.5892, Train Acc: 0.9636, Val Loss: 0.7556, Val Acc: 0.8942
# Epoch 49/200 - Train Loss: 0.5845, Train Acc: 0.9660, Val Loss: 0.7527, Val Acc: 0.8969
# Epoch 50/200 - Train Loss: 0.5823, Train Acc: 0.9660, Val Loss: 0.7540, Val Acc: 0.8917
# Epoch 51/200 - Train Loss: 0.5827, Train Acc: 0.9663, Val Loss: 0.7560, Val Acc: 0.8957
# Epoch 52/200 - Train Loss: 0.5835, Train Acc: 0.9662, Val Loss: 0.7513, Val Acc: 0.8954
# Epoch 53/200 - Train Loss: 0.5829, Train Acc: 0.9652, Val Loss: 0.7516, Val Acc: 0.8942
# Epoch 54/200 - Train Loss: 0.5830, Train Acc: 0.9650, Val Loss: 0.7544, Val Acc: 0.8935
# Epoch 55/200 - Train Loss: 0.5797, Train Acc: 0.9669, Val Loss: 0.7556, Val Acc: 0.8951
# Epoch 56/200 - Train Loss: 0.5812, Train Acc: 0.9667, Val Loss: 0.7587, Val Acc: 0.8914
# Epoch 57/200 - Train Loss: 0.5819, Train Acc: 0.9675, Val Loss: 0.7550, Val Acc: 0.8948
# Epoch 58/200 - Train Loss: 0.5812, Train Acc: 0.9673, Val Loss: 0.7590, Val Acc: 0.8917
# Epoch 59/200 - Train Loss: 0.5824, Train Acc: 0.9666, Val Loss: 0.7563, Val Acc: 0.8923
# Epoch 60/200 - Train Loss: 0.5821, Train Acc: 0.9675, Val Loss: 0.7583, Val Acc: 0.8920
# Epoch 61/200 - Train Loss: 0.5818, Train Acc: 0.9668, Val Loss: 0.7564, Val Acc: 0.8923
# Epoch 62/200 - Train Loss: 0.5814, Train Acc: 0.9671, Val Loss: 0.7546, Val Acc: 0.8942
# Epoch 63/200 - Train Loss: 0.5801, Train Acc: 0.9677, Val Loss: 0.7534, Val Acc: 0.8945
# Epoch 64/200 - Train Loss: 0.5817, Train Acc: 0.9664, Val Loss: 0.7575, Val Acc: 0.8908
# Epoch 65/200 - Train Loss: 0.5791, Train Acc: 0.9681, Val Loss: 0.7540, Val Acc: 0.8945
# Epoch 66/200 - Train Loss: 0.5756, Train Acc: 0.9709, Val Loss: 0.7562, Val Acc: 0.8939
# Epoch 67/200 - Train Loss: 0.5822, Train Acc: 0.9664, Val Loss: 0.7537, Val Acc: 0.8926
# Epoch 68/200 - Train Loss: 0.5810, Train Acc: 0.9675, Val Loss: 0.7569, Val Acc: 0.8920
# Epoch 69/200 - Train Loss: 0.5809, Train Acc: 0.9667, Val Loss: 0.7522, Val Acc: 0.8942
# Epoch 70/200 - Train Loss: 0.5792, Train Acc: 0.9665, Val Loss: 0.7564, Val Acc: 0.8926
# Epoch 71/200 - Train Loss: 0.5785, Train Acc: 0.9680, Val Loss: 0.7580, Val Acc: 0.8929
# Epoch 72/200 - Train Loss: 0.5780, Train Acc: 0.9688, Val Loss: 0.7526, Val Acc: 0.8960
# Epoch 73/200 - Train Loss: 0.5784, Train Acc: 0.9692, Val Loss: 0.7546, Val Acc: 0.8939
# Epoch 74/200 - Train Loss: 0.5808, Train Acc: 0.9676, Val Loss: 0.7572, Val Acc: 0.8917
# Epoch 75/200 - Train Loss: 0.5807, Train Acc: 0.9677, Val Loss: 0.7530, Val Acc: 0.8939
# Epoch 76/200 - Train Loss: 0.5798, Train Acc: 0.9678, Val Loss: 0.7548, Val Acc: 0.8939
# Epoch 77/200 - Train Loss: 0.5782, Train Acc: 0.9691, Val Loss: 0.7592, Val Acc: 0.8902
# Epoch 78/200 - Train Loss: 0.5809, Train Acc: 0.9672, Val Loss: 0.7557, Val Acc: 0.8926
# Epoch 79/200 - Train Loss: 0.5792, Train Acc: 0.9690, Val Loss: 0.7572, Val Acc: 0.8929
# Epoch 80/200 - Train Loss: 0.5798, Train Acc: 0.9676, Val Loss: 0.7531, Val Acc: 0.8945
# Epoch 81/200 - Train Loss: 0.5801, Train Acc: 0.9678, Val Loss: 0.7585, Val Acc: 0.8911
# Epoch 82/200 - Train Loss: 0.5782, Train Acc: 0.9687, Val Loss: 0.7538, Val Acc: 0.8948
# Epoch 83/200 - Train Loss: 0.5789, Train Acc: 0.9688, Val Loss: 0.7533, Val Acc: 0.8929
# Epoch 84/200 - Train Loss: 0.5807, Train Acc: 0.9672, Val Loss: 0.7578, Val Acc: 0.8917
# Epoch 85/200 - Train Loss: 0.5811, Train Acc: 0.9672, Val Loss: 0.7574, Val Acc: 0.8917
# Epoch 86/200 - Train Loss: 0.5807, Train Acc: 0.9674, Val Loss: 0.7567, Val Acc: 0.8926
# Epoch 87/200 - Train Loss: 0.5803, Train Acc: 0.9681, Val Loss: 0.7558, Val Acc: 0.8929
# Epoch 88/200 - Train Loss: 0.5792, Train Acc: 0.9679, Val Loss: 0.7547, Val Acc: 0.8945
# Epoch 89/200 - Train Loss: 0.5795, Train Acc: 0.9680, Val Loss: 0.7539, Val Acc: 0.8917
# Epoch 90/200 - Train Loss: 0.5784, Train Acc: 0.9709, Val Loss: 0.7565, Val Acc: 0.8923
# Epoch 91/200 - Train Loss: 0.5819, Train Acc: 0.9674, Val Loss: 0.7551, Val Acc: 0.8932
# Epoch 92/200 - Train Loss: 0.5803, Train Acc: 0.9684, Val Loss: 0.7536, Val Acc: 0.8960
# Epoch 93/200 - Train Loss: 0.5759, Train Acc: 0.9704, Val Loss: 0.7566, Val Acc: 0.8942
# Epoch 94/200 - Train Loss: 0.5782, Train Acc: 0.9688, Val Loss: 0.7534, Val Acc: 0.8945
# Epoch 95/200 - Train Loss: 0.5784, Train Acc: 0.9694, Val Loss: 0.7563, Val Acc: 0.8939
# Epoch 96/200 - Train Loss: 0.5814, Train Acc: 0.9664, Val Loss: 0.7525, Val Acc: 0.8939
# Epoch 97/200 - Train Loss: 0.5795, Train Acc: 0.9682, Val Loss: 0.7540, Val Acc: 0.8920
# Epoch 98/200 - Train Loss: 0.5802, Train Acc: 0.9680, Val Loss: 0.7521, Val Acc: 0.8945
# Epoch 99/200 - Train Loss: 0.5829, Train Acc: 0.9666, Val Loss: 0.7541, Val Acc: 0.8945
# Epoch 100/200 - Train Loss: 0.5803, Train Acc: 0.9676, Val Loss: 0.7538, Val Acc: 0.8942
# Epoch 101/200 - Train Loss: 0.5799, Train Acc: 0.9690, Val Loss: 0.7562, Val Acc: 0.8935
# Epoch 102/200 - Train Loss: 0.5772, Train Acc: 0.9679, Val Loss: 0.7541, Val Acc: 0.8951
# Epoch 103/200 - Train Loss: 0.5794, Train Acc: 0.9677, Val Loss: 0.7549, Val Acc: 0.8942
# Epoch 104/200 - Train Loss: 0.5793, Train Acc: 0.9689, Val Loss: 0.7551, Val Acc: 0.8923
# Epoch 105/200 - Train Loss: 0.5804, Train Acc: 0.9677, Val Loss: 0.7570, Val Acc: 0.8914
# Epoch 106/200 - Train Loss: 0.5807, Train Acc: 0.9673, Val Loss: 0.7530, Val Acc: 0.8948
# Epoch 107/200 - Train Loss: 0.5784, Train Acc: 0.9697, Val Loss: 0.7544, Val Acc: 0.8929
# Epoch 108/200 - Train Loss: 0.5805, Train Acc: 0.9682, Val Loss: 0.7562, Val Acc: 0.8942
# Epoch 109/200 - Train Loss: 0.5797, Train Acc: 0.9670, Val Loss: 0.7549, Val Acc: 0.8929
# Epoch 110/200 - Train Loss: 0.5804, Train Acc: 0.9677, Val Loss: 0.7565, Val Acc: 0.8926
# Epoch 111/200 - Train Loss: 0.5778, Train Acc: 0.9688, Val Loss: 0.7544, Val Acc: 0.8935
# Epoch 112/200 - Train Loss: 0.5799, Train Acc: 0.9685, Val Loss: 0.7589, Val Acc: 0.8914
# Epoch 113/200 - Train Loss: 0.5769, Train Acc: 0.9685, Val Loss: 0.7539, Val Acc: 0.8935
# Epoch 114/200 - Train Loss: 0.5780, Train Acc: 0.9691, Val Loss: 0.7566, Val Acc: 0.8914
# Epoch 115/200 - Train Loss: 0.5788, Train Acc: 0.9675, Val Loss: 0.7573, Val Acc: 0.8917
# Epoch 116/200 - Train Loss: 0.5799, Train Acc: 0.9680, Val Loss: 0.7544, Val Acc: 0.8951
# Epoch 117/200 - Train Loss: 0.5782, Train Acc: 0.9675, Val Loss: 0.7554, Val Acc: 0.8963
# Epoch 118/200 - Train Loss: 0.5793, Train Acc: 0.9688, Val Loss: 0.7553, Val Acc: 0.8914
# Epoch 119/200 - Train Loss: 0.5772, Train Acc: 0.9697, Val Loss: 0.7554, Val Acc: 0.8954
# Epoch 120/200 - Train Loss: 0.5791, Train Acc: 0.9681, Val Loss: 0.7544, Val Acc: 0.8932
# Epoch 121/200 - Train Loss: 0.5799, Train Acc: 0.9666, Val Loss: 0.7552, Val Acc: 0.8942
# Epoch 122/200 - Train Loss: 0.5785, Train Acc: 0.9686, Val Loss: 0.7561, Val Acc: 0.8926
# Epoch 123/200 - Train Loss: 0.5791, Train Acc: 0.9684, Val Loss: 0.7574, Val Acc: 0.8926
# Epoch 124/200 - Train Loss: 0.5802, Train Acc: 0.9679, Val Loss: 0.7580, Val Acc: 0.8926
# Epoch 125/200 - Train Loss: 0.5818, Train Acc: 0.9685, Val Loss: 0.7581, Val Acc: 0.8935
# Epoch 126/200 - Train Loss: 0.5784, Train Acc: 0.9686, Val Loss: 0.7581, Val Acc: 0.8929
# Epoch 127/200 - Train Loss: 0.5805, Train Acc: 0.9673, Val Loss: 0.7541, Val Acc: 0.8948
# Epoch 128/200 - Train Loss: 0.5808, Train Acc: 0.9662, Val Loss: 0.7564, Val Acc: 0.8942
# Epoch 129/200 - Train Loss: 0.5804, Train Acc: 0.9679, Val Loss: 0.7546, Val Acc: 0.8923
# Epoch 130/200 - Train Loss: 0.5808, Train Acc: 0.9667, Val Loss: 0.7534, Val Acc: 0.8926
# Epoch 131/200 - Train Loss: 0.5787, Train Acc: 0.9694, Val Loss: 0.7542, Val Acc: 0.8932
# Epoch 132/200 - Train Loss: 0.5781, Train Acc: 0.9679, Val Loss: 0.7580, Val Acc: 0.8920
# Epoch 133/200 - Train Loss: 0.5779, Train Acc: 0.9671, Val Loss: 0.7537, Val Acc: 0.8945
# Epoch 134/200 - Train Loss: 0.5800, Train Acc: 0.9685, Val Loss: 0.7554, Val Acc: 0.8957
# Epoch 135/200 - Train Loss: 0.5776, Train Acc: 0.9692, Val Loss: 0.7562, Val Acc: 0.8929
# Epoch 136/200 - Train Loss: 0.5824, Train Acc: 0.9673, Val Loss: 0.7528, Val Acc: 0.8942
# Epoch 137/200 - Train Loss: 0.5816, Train Acc: 0.9676, Val Loss: 0.7547, Val Acc: 0.8929
# Epoch 138/200 - Train Loss: 0.5806, Train Acc: 0.9680, Val Loss: 0.7549, Val Acc: 0.8926
# Epoch 139/200 - Train Loss: 0.5775, Train Acc: 0.9697, Val Loss: 0.7559, Val Acc: 0.8932
# Epoch 140/200 - Train Loss: 0.5786, Train Acc: 0.9683, Val Loss: 0.7583, Val Acc: 0.8902
# Epoch 141/200 - Train Loss: 0.5790, Train Acc: 0.9693, Val Loss: 0.7589, Val Acc: 0.8914
# Epoch 142/200 - Train Loss: 0.5787, Train Acc: 0.9690, Val Loss: 0.7537, Val Acc: 0.8939
# Epoch 143/200 - Train Loss: 0.5792, Train Acc: 0.9692, Val Loss: 0.7568, Val Acc: 0.8929
# Epoch 144/200 - Train Loss: 0.5806, Train Acc: 0.9685, Val Loss: 0.7544, Val Acc: 0.8939
# Epoch 145/200 - Train Loss: 0.5801, Train Acc: 0.9668, Val Loss: 0.7549, Val Acc: 0.8920
# Epoch 146/200 - Train Loss: 0.5804, Train Acc: 0.9670, Val Loss: 0.7526, Val Acc: 0.8935
# Epoch 147/200 - Train Loss: 0.5790, Train Acc: 0.9685, Val Loss: 0.7583, Val Acc: 0.8923
# Epoch 148/200 - Train Loss: 0.5795, Train Acc: 0.9683, Val Loss: 0.7560, Val Acc: 0.8914
# Epoch 149/200 - Train Loss: 0.5788, Train Acc: 0.9692, Val Loss: 0.7548, Val Acc: 0.8932
# Epoch 150/200 - Train Loss: 0.5806, Train Acc: 0.9677, Val Loss: 0.7550, Val Acc: 0.8960
# Epoch 151/200 - Train Loss: 0.5818, Train Acc: 0.9667, Val Loss: 0.7558, Val Acc: 0.8926
# Epoch 152/200 - Train Loss: 0.5808, Train Acc: 0.9681, Val Loss: 0.7560, Val Acc: 0.8920
# Epoch 153/200 - Train Loss: 0.5807, Train Acc: 0.9678, Val Loss: 0.7568, Val Acc: 0.8923
# Epoch 154/200 - Train Loss: 0.5795, Train Acc: 0.9690, Val Loss: 0.7588, Val Acc: 0.8899
# Epoch 155/200 - Train Loss: 0.5812, Train Acc: 0.9669, Val Loss: 0.7540, Val Acc: 0.8945
# Epoch 156/200 - Train Loss: 0.5803, Train Acc: 0.9685, Val Loss: 0.7544, Val Acc: 0.8945
# Epoch 157/200 - Train Loss: 0.5761, Train Acc: 0.9696, Val Loss: 0.7530, Val Acc: 0.8929
# Epoch 158/200 - Train Loss: 0.5813, Train Acc: 0.9675, Val Loss: 0.7554, Val Acc: 0.8914
# Epoch 159/200 - Train Loss: 0.5795, Train Acc: 0.9677, Val Loss: 0.7558, Val Acc: 0.8945
# Epoch 160/200 - Train Loss: 0.5787, Train Acc: 0.9690, Val Loss: 0.7573, Val Acc: 0.8923
# Epoch 161/200 - Train Loss: 0.5805, Train Acc: 0.9666, Val Loss: 0.7529, Val Acc: 0.8929
# Epoch 162/200 - Train Loss: 0.5787, Train Acc: 0.9685, Val Loss: 0.7598, Val Acc: 0.8920
# Epoch 163/200 - Train Loss: 0.5787, Train Acc: 0.9682, Val Loss: 0.7530, Val Acc: 0.8945
# Epoch 164/200 - Train Loss: 0.5797, Train Acc: 0.9683, Val Loss: 0.7546, Val Acc: 0.8945
# Epoch 165/200 - Train Loss: 0.5773, Train Acc: 0.9687, Val Loss: 0.7585, Val Acc: 0.8929
# Epoch 166/200 - Train Loss: 0.5800, Train Acc: 0.9681, Val Loss: 0.7553, Val Acc: 0.8929
# Epoch 167/200 - Train Loss: 0.5784, Train Acc: 0.9692, Val Loss: 0.7539, Val Acc: 0.8939
# Epoch 168/200 - Train Loss: 0.5790, Train Acc: 0.9700, Val Loss: 0.7586, Val Acc: 0.8905
# Epoch 169/200 - Train Loss: 0.5797, Train Acc: 0.9664, Val Loss: 0.7552, Val Acc: 0.8945
# Epoch 170/200 - Train Loss: 0.5792, Train Acc: 0.9678, Val Loss: 0.7524, Val Acc: 0.8926
# Epoch 171/200 - Train Loss: 0.5795, Train Acc: 0.9677, Val Loss: 0.7554, Val Acc: 0.8945
# Epoch 172/200 - Train Loss: 0.5798, Train Acc: 0.9673, Val Loss: 0.7554, Val Acc: 0.8935
# Epoch 173/200 - Train Loss: 0.5798, Train Acc: 0.9671, Val Loss: 0.7569, Val Acc: 0.8911
# Epoch 174/200 - Train Loss: 0.5817, Train Acc: 0.9679, Val Loss: 0.7573, Val Acc: 0.8929
# Epoch 175/200 - Train Loss: 0.5796, Train Acc: 0.9674, Val Loss: 0.7574, Val Acc: 0.8920
# Epoch 176/200 - Train Loss: 0.5794, Train Acc: 0.9683, Val Loss: 0.7600, Val Acc: 0.8902
# Epoch 177/200 - Train Loss: 0.5802, Train Acc: 0.9687, Val Loss: 0.7520, Val Acc: 0.8960
# Epoch 178/200 - Train Loss: 0.5785, Train Acc: 0.9692, Val Loss: 0.7542, Val Acc: 0.8945
# Epoch 179/200 - Train Loss: 0.5772, Train Acc: 0.9694, Val Loss: 0.7555, Val Acc: 0.8951
# Epoch 180/200 - Train Loss: 0.5811, Train Acc: 0.9670, Val Loss: 0.7541, Val Acc: 0.8929
# Epoch 181/200 - Train Loss: 0.5761, Train Acc: 0.9695, Val Loss: 0.7570, Val Acc: 0.8935
# Epoch 182/200 - Train Loss: 0.5771, Train Acc: 0.9693, Val Loss: 0.7534, Val Acc: 0.8935
# Epoch 183/200 - Train Loss: 0.5786, Train Acc: 0.9684, Val Loss: 0.7553, Val Acc: 0.8942
# Epoch 184/200 - Train Loss: 0.5816, Train Acc: 0.9678, Val Loss: 0.7550, Val Acc: 0.8939
# Epoch 185/200 - Train Loss: 0.5803, Train Acc: 0.9667, Val Loss: 0.7560, Val Acc: 0.8929
# Epoch 186/200 - Train Loss: 0.5806, Train Acc: 0.9679, Val Loss: 0.7576, Val Acc: 0.8920
# Epoch 187/200 - Train Loss: 0.5820, Train Acc: 0.9652, Val Loss: 0.7573, Val Acc: 0.8926
# Epoch 188/200 - Train Loss: 0.5794, Train Acc: 0.9676, Val Loss: 0.7540, Val Acc: 0.8948
# Epoch 189/200 - Train Loss: 0.5777, Train Acc: 0.9704, Val Loss: 0.7579, Val Acc: 0.8926
# Epoch 190/200 - Train Loss: 0.5787, Train Acc: 0.9680, Val Loss: 0.7548, Val Acc: 0.8945
# Epoch 191/200 - Train Loss: 0.5785, Train Acc: 0.9685, Val Loss: 0.7558, Val Acc: 0.8945
# Epoch 192/200 - Train Loss: 0.5780, Train Acc: 0.9687, Val Loss: 0.7546, Val Acc: 0.8945
# Epoch 193/200 - Train Loss: 0.5779, Train Acc: 0.9681, Val Loss: 0.7548, Val Acc: 0.8929
# Epoch 194/200 - Train Loss: 0.5764, Train Acc: 0.9698, Val Loss: 0.7546, Val Acc: 0.8939
# Epoch 195/200 - Train Loss: 0.5802, Train Acc: 0.9671, Val Loss: 0.7576, Val Acc: 0.8945
# Epoch 196/200 - Train Loss: 0.5782, Train Acc: 0.9688, Val Loss: 0.7526, Val Acc: 0.8951
# Epoch 197/200 - Train Loss: 0.5790, Train Acc: 0.9683, Val Loss: 0.7570, Val Acc: 0.8908
# Epoch 198/200 - Train Loss: 0.5812, Train Acc: 0.9677, Val Loss: 0.7579, Val Acc: 0.8932
# Epoch 199/200 - Train Loss: 0.5802, Train Acc: 0.9682, Val Loss: 0.7564, Val Acc: 0.8926
# Epoch 200/200 - Train Loss: 0.5768, Train Acc: 0.9686, Val Loss: 0.7548, Val Acc: 0.8929
# Test Accuracy: 0.897796817625459
# Test Balanced Accuracy: 0.7718742680333444
# Test Precision: 0.8969293921258662
# Test Recall: 0.897796817625459
# Test F1 Score: 0.8969827417042051

# %% [markdown]
# ## Classification Report
#
# Generates a full precision-recall-F1 summary for each class, providing a detailed view of per-class performance on the test set.

# %%
# Display a detailed classification report
print("\nClassification Report:")
print(classification_report(test_true, test_preds, target_names=class_names))
# Out:
# Classification Report:
#                    precision    recall  f1-score   support
#
#     barred_spiral       0.82      0.80      0.81       136
#      cigar_smooth       0.92      0.92      0.92       944
#   edgeon_no_bulge       0.90      0.67      0.77        52
# edgeon_with_bulge       0.92      0.97      0.94       230
#  inbetween_smooth       0.94      0.95      0.94      1050
#            merger       0.88      0.82      0.85        78
#      round_smooth       0.80      0.82      0.81       519
#      spiral_loose       0.87      0.84      0.85       168
#     spiral_medium       0.88      0.94      0.91        88
#      spiral_tight       0.00      0.00      0.00         3
#
#          accuracy                           0.90      3268
#         macro avg       0.79      0.77      0.78      3268
#      weighted avg       0.90      0.90      0.90      3268

# %% [markdown]
# ## Confusion Matrix Visualization
#
# Plots two confusion matrices: one with raw prediction counts and another with row-normalized percentages. These visualizations help assess which classes the model confuses most often.

# %%
# Plot confusion matrix with raw prediction counts
cm = confusion_matrix(test_true, test_preds)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_names)

fig, ax = plt.subplots(figsize=(10, 10))
disp.plot(ax=ax, cmap='Purples', xticks_rotation=45)

ax.set_title("Confusion Matrix", fontsize=20, pad=20)
ax.set_xlabel(ax.get_xlabel(), fontsize=18)
ax.set_ylabel(ax.get_ylabel(), fontsize=18)
ax.tick_params(axis='both', labelsize=14)
for text in disp.text_.ravel():
    text.set_fontsize(14)

plt.show()

# Plot confusion matrix with row-normalized percentages
cm_percent = cm.astype(float) / cm.sum(axis=1)[:, None] * 100
disp_percent = ConfusionMatrixDisplay(confusion_matrix=cm_percent, display_labels=class_names)

fig, ax = plt.subplots(figsize=(10, 10))
disp_percent.plot(ax=ax, cmap='Purples', xticks_rotation=45, values_format='.1f')

for text in disp_percent.text_.ravel():
    text.set_text(f"{float(text.get_text()):.1f}%")
    text.set_fontsize(14)

ax.set_title("Confusion Matrix (Percent per Row)", fontsize=20, pad=20)
ax.set_xlabel(ax.get_xlabel(), fontsize=18)
ax.set_ylabel(ax.get_ylabel(), fontsize=18)
ax.tick_params(axis='both', labelsize=14)

plt.show()

# %% [markdown]
# ## Hierarchical Clustering of Predicted Classes
#
# We analyzed how the model groups Galaxy10 classes by performing hierarchical clustering based on the **mean embedding** (centroid) of each **predicted class** in the test set.
#
# For each class that was actually predicted by the model, we computed its centroid by averaging the embeddings of all test samples assigned to that class. This approach reflects how the model internally organizes its predictions in feature space.
#
# We used **Ward’s method** on the pairwise **Euclidean distances** between class centroids:
#
# $$
# \text{Distance}(C_i, C_j) = \left\| \mu_i - \mu_j \right\|_2
# $$
#
# This method reveals how semantically close the predicted classes are according to the model’s learned representation.
#
# > Note: Classes not predicted at all are excluded from the dendrogram.

# %%
# Extract embeddings and predictions for the test set
model.eval()
feature_extractor = nn.Sequential(*list(model.children())[:-1]).to(device)  # Remove final classification layer

test_emb_list, test_pred_list = [], []

with torch.no_grad():
    for x, _ in test_loader:
        x = x.to(device)
        feats = feature_extractor(x).flatten(1)  # Extract features of shape (B, 2048)
        logits = model.fc(feats)  # Compute class scores
        preds = logits.argmax(1)  # Get predicted class indices
        test_emb_list.append(feats.cpu())
        test_pred_list.append(preds.cpu())

# Combine all batch results
test_embeddings = torch.cat(test_emb_list).numpy()  # Shape: (N, 2048)
test_preds = torch.cat(test_pred_list).numpy()  # Shape: (N,)

# Compute centroids for each predicted class
class_names = np.array(class_names)
centroids_pred, valid_class_names_pred = [], []
for cls in np.unique(test_preds):
    idx = np.where(test_preds == cls)[0]  # Indices for the current class
    centroids_pred.append(test_embeddings[idx].mean(axis=0))
    valid_class_names_pred.append(class_names[cls])
centroids_pred = np.vstack(centroids_pred)

# Perform hierarchical clustering and plot dendrogram
linked_pred = linkage(centroids_pred, method='ward')
plt.figure(figsize=(14, 7))
dendrogram(linked_pred, labels=valid_class_names_pred, leaf_rotation=90)
plt.title('Hierarchical Clustering of Predicted Classes (ResNet-101 Embeddings)')
plt.xlabel('Predicted Classes')
plt.ylabel('Distance')
plt.show()
